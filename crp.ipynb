# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn import metrics

# %% [markdown]
# BHIHAR CRIME DATASET

# %%
# Load the dataset
dataset = pd.read_excel("Dataset/bcrp.xlsx", sheet_name="bcrp")

# %%
dataset
# Out:
#                          City  Year  Population  (in Lakhs)  Murder  Dacoity  \
# 0                      Araria  2018                   28.12      80        8
# 1                      Araria  2019                   28.12      98        7
# 2                      Araria  2020                   28.90     104        6
# 3                      Araria  2021                   28.10      64        3
# 4                       Arwal  2018                    7.01      35        5
# ..                        ...   ...                     ...     ...      ...
# 147        Vaishali (Hajipur)  2021                   39.10     110       12
# 148  West Champaran (Bettiah)  2018                   39.35     111       10
# 149  West Champaran (Bettiah)  2019                   40.60     106        4
# 150  West Champaran (Bettiah)  2020                   42.09     124        6
# 151  West Champaran (Bettiah)  2021                   39.40     103        6
#
#      Robbery  Burglary  Theft  Kidnapping & Abduction  Rape  Riots  \
# 0         31        77    428                     250    25    330
# 1         28        65    521                     429    66    265
# 2         19        42    347                     252    29    223
# 3         18        47   3020                     209     6    154
# 4         10        28    153                      48     9     79
# ..       ...       ...    ...                     ...   ...    ...
# 147       50        95   4520                     329    14    278
# 148       41       106    702                     330    34    410
# 149       22        41    489                     402    61    243
# 150       35        73   1006                     294    37    355
# 151       41        82   4050                     327     9    248
#
#      Dowry Deaths  Cruelty by Husband/Relatives  Attempt to Murder  \
# 0              18                            51                124
# 1              53                            92                118
# 2              18                            99                189
# 3               8                           128                 47
# 4               9                            14                 65
# ..            ...                           ...                ...
# 147            18                           241                 95
# 148            25                            59                172
# 149            39                            83                115
# 150            41                           159                308
# 151            14                           188                 82
#
#      Total Violent Crimes
# 0                     710
# 1                    1136
# 2                     902
# 3                     936
# 4                     276
# ..                    ...
# 147                  1517
# 148                  1040
# 149                  1205
# 150                  1507
# 151                  1334
#
# [152 rows x 15 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   City                          152 non-null    str
#  1   Year                          152 non-null    int64
#  2   Population  (in Lakhs)        152 non-null    float64
#  3   Murder                        152 non-null    int64
#  4   Dacoity                       152 non-null    int64
#  5   Robbery                       152 non-null    int64
#  6   Burglary                      152 non-null    int64
#  7   Theft                         152 non-null    int64
#  8   Kidnapping & Abduction        152 non-null    int64
#  9   Rape                          152 non-null    int64
#  10  Riots                         152 non-null    int64
#  11  Dowry Deaths                  152 non-null    int64
#  12  Cruelty by Husband/Relatives  152 non-null    int64
#  13  Attempt to Murder             152 non-null    int64
#  14  Total Violent Crimes          152 non-null    int64
# dtypes: float64(1), int64(13), str(1)
# memory usage: 17.9 KB

# %% [markdown]
# DATA VISUALISATION

# %%
fig, ax = plt.subplots(13, 1, figsize=(21, 350))

for i in range(0, 13):
    ax[i].barh(dataset['City'], dataset[dataset.columns[i+2]], 0.6, color='Salmon')
    ax[i].set_title('City vs ' + dataset.columns[i+2])
plt.show()

# %%
new_df = pd.DataFrame(columns=['Year', 'City',  'Number Of Cases', 'Type'])
for i in range(3, 15):
    temp = dataset[['Year', 'City','Population  (in Lakhs)' ]].copy()
    temp['Number Of Cases'] = dataset.iloc[:, i].values
    temp['Type'] = dataset.columns[i]
    new_df = pd.concat([new_df, temp], ignore_index=True)

# %%
new_df
# Out:
#       Year                      City Number Of Cases                  Type  \
# 0     2018                    Araria              80                Murder
# 1     2019                    Araria              98                Murder
# 2     2020                    Araria             104                Murder
# 3     2021                    Araria              64                Murder
# 4     2018                     Arwal              35                Murder
# ...    ...                       ...             ...                   ...
# 1819  2021        Vaishali (Hajipur)            1517  Total Violent Crimes
# 1820  2018  West Champaran (Bettiah)            1040  Total Violent Crimes
# 1821  2019  West Champaran (Bettiah)            1205  Total Violent Crimes
# 1822  2020  West Champaran (Bettiah)            1507  Total Violent Crimes
# 1823  2021  West Champaran (Bettiah)            1334  Total Violent Crimes
#
#       Population  (in Lakhs)
# 0                      28.12
# 1                      28.12
# 2                      28.90
# 3                      28.10
# 4                       7.01
# ...                      ...
# 1819                   39.10
# 1820                   39.35
# 1821                   40.60
# 1822                   42.09
# 1823                   39.40
#
# [1824 rows x 5 columns]

# %% [markdown]
# DATA PRE-PROCESSING

# %%
new_df['Crime Rate'] = pd.to_numeric(new_df['Number Of Cases'], errors='coerce') / new_df['Population  (in Lakhs)']

# %%
new_df
# Out:
#       Year                      City Number Of Cases                  Type  \
# 0     2018                    Araria              80                Murder
# 1     2019                    Araria              98                Murder
# 2     2020                    Araria             104                Murder
# 3     2021                    Araria              64                Murder
# 4     2018                     Arwal              35                Murder
# ...    ...                       ...             ...                   ...
# 1819  2021        Vaishali (Hajipur)            1517  Total Violent Crimes
# 1820  2018  West Champaran (Bettiah)            1040  Total Violent Crimes
# 1821  2019  West Champaran (Bettiah)            1205  Total Violent Crimes
# 1822  2020  West Champaran (Bettiah)            1507  Total Violent Crimes
# 1823  2021  West Champaran (Bettiah)            1334  Total Violent Crimes
#
#       Population  (in Lakhs)  Crime Rate
# 0                      28.12    2.844950
# 1                      28.12    3.485064
# 2                      28.90    3.598616
# 3                      28.10    2.277580
# 4                       7.01    4.992867
# ...                      ...         ...
# 1819                   39.10   38.797954
# 1820                   39.35   26.429479
# 1821                   40.60   29.679803
# 1822                   42.09   35.804229
# 1823                   39.40   33.857868
#
# [1824 rows x 6 columns]

# %%
new_df = new_df.drop(['Number Of Cases'], axis=1)

# %%
new_df
# Out:
#       Year                      City                  Type  \
# 0     2018                    Araria                Murder
# 1     2019                    Araria                Murder
# 2     2020                    Araria                Murder
# 3     2021                    Araria                Murder
# 4     2018                     Arwal                Murder
# ...    ...                       ...                   ...
# 1819  2021        Vaishali (Hajipur)  Total Violent Crimes
# 1820  2018  West Champaran (Bettiah)  Total Violent Crimes
# 1821  2019  West Champaran (Bettiah)  Total Violent Crimes
# 1822  2020  West Champaran (Bettiah)  Total Violent Crimes
# 1823  2021  West Champaran (Bettiah)  Total Violent Crimes
#
#       Population  (in Lakhs)  Crime Rate
# 0                      28.12    2.844950
# 1                      28.12    3.485064
# 2                      28.90    3.598616
# 3                      28.10    2.277580
# 4                       7.01    4.992867
# ...                      ...         ...
# 1819                   39.10   38.797954
# 1820                   39.35   26.429479
# 1821                   40.60   29.679803
# 1822                   42.09   35.804229
# 1823                   39.40   33.857868
#
# [1824 rows x 5 columns]

# %%
# saving the new dataset as an excel file
new_df.to_excel("Dataset/new_dataset.xlsx", index=False, sheet_name ='Sheet1')

# %%
new_dataset = pd.read_excel("Dataset/new_dataset.xlsx", sheet_name="Sheet1")

# %%
new_dataset
# Out:
#       Year                      City                  Type  \
# 0     2018                    Araria                Murder
# 1     2019                    Araria                Murder
# 2     2020                    Araria                Murder
# 3     2021                    Araria                Murder
# 4     2018                     Arwal                Murder
# ...    ...                       ...                   ...
# 1819  2021        Vaishali (Hajipur)  Total Violent Crimes
# 1820  2018  West Champaran (Bettiah)  Total Violent Crimes
# 1821  2019  West Champaran (Bettiah)  Total Violent Crimes
# 1822  2020  West Champaran (Bettiah)  Total Violent Crimes
# 1823  2021  West Champaran (Bettiah)  Total Violent Crimes
#
#       Population  (in Lakhs)  Crime Rate
# 0                      28.12    2.844950
# 1                      28.12    3.485064
# 2                      28.90    3.598616
# 3                      28.10    2.277580
# 4                       7.01    4.992867
# ...                      ...         ...
# 1819                   39.10   38.797954
# 1820                   39.35   26.429479
# 1821                   40.60   29.679803
# 1822                   42.09   35.804229
# 1823                   39.40   33.857868
#
# [1824 rows x 5 columns]

# %%
new_dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1824 entries, 0 to 1823
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    1824 non-null   int64
#  1   City                    1824 non-null   str
#  2   Type                    1824 non-null   str
#  3   Population  (in Lakhs)  1824 non-null   float64
#  4   Crime Rate              1824 non-null   float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 71.4 KB

# %%
new_dataset.describe()
# Out:
#               Year  Population  (in Lakhs)   Crime Rate
# count  1824.000000             1824.000000  1824.000000
# mean   2019.500000               28.574145    10.077591
# std       1.118341               13.536800    22.816444
# min    2018.000000                6.360000     0.000000
# 25%    2018.750000               17.555000     0.928834
# 50%    2019.500000               28.915000     2.855167
# 75%    2020.250000               37.577500     8.827486
# max    2021.000000               69.200000   249.682081

# %%
le = LabelEncoder()

# %%
new_dataset['City'] = le.fit_transform(new_dataset['City'])
mapping = dict(zip(le.classes_, range(len(le.classes_))))

# %%
# Saving the mapping file for further use
file = open('Mappings/City_Mapping.txt', 'wt')
for key,val in mapping.items():
    print(str(key) + " - " + str(val) + '\n')
    file.write(str(key) + " - " + str(val) + '\n')
# Out:
# Araria - 0
#
# Arwal - 1
#
# Aurangabad - 2
#
# Banka - 3
#
# Begusarai - 4
#
# Bhagalpur - 5
#
# Bhojpur - 6
#
# Buxar - 7
#
# Darbhanga - 8
#
# East Champaran (Motihari) - 9
#
# Gaya - 10
#
# Gopalganj - 11
#
# Jamui - 12
#
# Jehanabad - 13
#
# Kaimur (Bhabua) - 14
#
# Katihar - 15
#
# Khagaria - 16
#
# Kishanganj - 17
#
# Lakhisarai - 18
#
# Madhepura - 19
#
# Madhubani - 20
#
# Munger - 21
#
# Muzaffarpur - 22
#
# Nalanda - 23
#
# Nawada - 24
#
# Patna - 25
#
# Purnia - 26
#
# Rohtas - 27
#
# Saharsa - 28
#
# Samastipur - 29
#
# Saran (Chhapra) - 30
#
# Sheikhpura - 31
#
# Sheohar - 32
#
# Sitamarhi - 33
#
# Siwan - 34
#
# Supaul - 35
#
# Vaishali (Hajipur) - 36
#
# West Champaran (Bettiah) - 37

# %%
new_dataset['Type'] = le.fit_transform(new_dataset['Type'])
mapping = dict(zip(le.classes_, range(len(le.classes_))))

# %%
# Saving the mapping file for further use
file = open('Mappings/Type_Mapping.txt', 'wt')
for key,val in mapping.items():
    print(str(key) + " - " + str(val) + '\n')
    file.write(str(key) + " - " + str(val) + '\n')
# Out:
# Attempt to Murder - 0
#
# Burglary - 1
#
# Cruelty by Husband/Relatives - 2
#
# Dacoity - 3
#
# Dowry Deaths - 4
#
# Kidnapping & Abduction - 5
#
# Murder - 6
#
# Rape - 7
#
# Riots - 8
#
# Robbery - 9
#
# Theft - 10
#
# Total Violent Crimes - 11

# %%
new_dataset
# Out:
#       Year  City  Type  Population  (in Lakhs)  Crime Rate
# 0     2018     0     6                   28.12    2.844950
# 1     2019     0     6                   28.12    3.485064
# 2     2020     0     6                   28.90    3.598616
# 3     2021     0     6                   28.10    2.277580
# 4     2018     1     6                    7.01    4.992867
# ...    ...   ...   ...                     ...         ...
# 1819  2021    36    11                   39.10   38.797954
# 1820  2018    37    11                   39.35   26.429479
# 1821  2019    37    11                   40.60   29.679803
# 1822  2020    37    11                   42.09   35.804229
# 1823  2021    37    11                   39.40   33.857868
#
# [1824 rows x 5 columns]

# %%
x = new_dataset[new_dataset.columns[0:4]].values
x
# Out:
# array([[2018.  ,    0.  ,    6.  ,   28.12],
#        [2019.  ,    0.  ,    6.  ,   28.12],
#        [2020.  ,    0.  ,    6.  ,   28.9 ],
#        ...,
#        [2019.  ,   37.  ,   11.  ,   40.6 ],
#        [2020.  ,   37.  ,   11.  ,   42.09],
#        [2021.  ,   37.  ,   11.  ,   39.4 ]])

# %%
y = new_dataset['Crime Rate'].values
y
# Out:
# array([ 2.84495021,  3.48506401,  3.59861592, ..., 29.67980296,
#        35.80422903, 33.85786802])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=50)

# %%
x_train
# Out:
# array([[2.018e+03, 1.500e+01, 5.000e+00, 3.071e+01],
#        [2.019e+03, 1.300e+01, 7.000e+00, 1.161e+01],
#        [2.021e+03, 3.400e+01, 6.000e+00, 3.530e+01],
#        ...,
#        [2.019e+03, 2.700e+01, 6.000e+00, 3.061e+01],
#        [2.018e+03, 3.400e+01, 2.000e+00, 3.330e+01],
#        [2.018e+03, 1.000e+01, 1.100e+01, 4.391e+01]])

# %%
y_train
# Out:
# array([ 8.07554542,  2.92850991,  2.97450425, ...,  3.95295655,
#         1.35135135, 25.71168299])

# %%
model1 = svm.SVR()
model1.fit(x_train, y_train)
y_pred = model1.predict(x_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('R2 score:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 8.652628122867737
# Mean Squared Error: 610.8521880628944
# R2 score: -0.08364015561419924

# %%
model2 = KNeighborsRegressor(n_neighbors=2)
model2.fit(x_train, y_train)
y_pred = model2.predict(x_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('R2 score:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 8.605333493805345
# Mean Squared Error: 536.476855108072
# R2 score: 0.048300269503379845

# %%
model3 = tree.DecisionTreeRegressor()
model3.fit(x_train, y_train)
y_pred = model3.predict(x_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('R2 score:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 2.7030104253936553
# Mean Squared Error: 82.61208296201487
# R2 score: 0.8534477371351356

# %%
model4 = RandomForestRegressor(random_state=0)
model4.fit(x_train, y_train)
y_pred = model4.predict(x_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('R2 score:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 2.198450596882441
# Mean Squared Error: 50.99092667804583
# R2 score: 0.9095430665550459

# %%
model5 = MLPRegressor(random_state=0)
model5.fit(x_train, y_train)
y_pred = model5.predict(x_test)
# Out:
# c:\Users\Satywan Prajapati\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('R2 score:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 9.406318001413247
# Mean Squared Error: 458.508804338166
# R2 score: 0.18661410764672048

# %%
import pickle

# %%
#saving the model as .pkl file
pkl_filename = "Model/model.pkl"
with open(pkl_filename, 'wb') as file:
    pickle.dump(model4, file)

# %%
#checking the saved model accuracy
with open(pkl_filename, 'rb') as file:
    pickle_model = pickle.load(file)
score = pickle_model.score(x_test, y_test)
print(score)
# Out:
# 0.9095430665550459
